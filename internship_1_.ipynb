# %% [markdown]
# #LEVEL 1

# %% [markdown]
# #Task 1

# %% [markdown]
# Data Exploration and Preprocessing

# %%
import pandas as pd

# %% [markdown]
# load

# %%
df = pd.read_csv('/content/Dataset .csv')

# %% [markdown]
# ...Explore the dataset and identify the number
# of rows and columns.

# %%
# Explore the dataset
num_rows, num_columns = df.shape
print(f"Dataset shape: {num_rows} rows x {num_columns} columns")
# Out:
# Dataset shape: 9551 rows x 21 columns

# %% [markdown]
# ...Check for missing values in each column and
# handle them accordingly.

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("\nMissing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ...handling them

# %%
# Handle missing values in 'Cuisines' (replace NaN with the mode)
df['Cuisines'].fillna(df['Cuisines'].mode()[0], inplace=True)

# %%
missing_values = df.isnull().sum()
print("\nMissing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ....Perform data type conversion if necessary.
# Analyze the distribution of the target variable
# ("Aggregate rating") and identify any class
# imbalances.

# %%
# Data type conversion (example: convert 'Votes' to float)
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')

# %%
# Analyze the target variable distribution
target_distribution = df['Aggregate rating'].value_counts()
print("\nDistribution of the target variable:")
print(target_distribution)
# Out:
# Distribution of the target variable:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
# Check for class imbalances
class_imbalances = df['Aggregate rating'].value_counts(normalize=True)
print("\nClass Imbalances:")
print(class_imbalances)
# Out:
# Class Imbalances:
# 0.0    0.224898
# 3.2    0.054654
# 3.1    0.054340
# 3.4    0.052141
# 3.3    0.050571
# 3.5    0.050257
# 3.0    0.049000
# 3.6    0.047953
# 3.7    0.044707
# 3.8    0.041880
# 2.9    0.039891
# 3.9    0.035075
# 2.8    0.032981
# 4.1    0.028688
# 4.0    0.027850
# 2.7    0.026175
# 4.2    0.023139
# 2.6    0.019998
# 4.3    0.018218
# 4.4    0.015077
# 2.5    0.011517
# 4.5    0.009947
# 2.4    0.009109
# 4.6    0.008167
# 4.9    0.006387
# 2.3    0.004921
# 4.7    0.004397
# 2.2    0.002827
# 4.8    0.002618
# 2.1    0.001571
# 2.0    0.000733
# 1.9    0.000209
# 1.8    0.000105
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# # Task 2

# %% [markdown]
# ...Calculate basic statistical measures (mean,
# median, standard deviation, etc.) for numerical
# columns.

# %%
# Calculate basic statistical measures for numerical columns
numerical_stats = df.describe()

# %%
# Display the results
print("\nBasic Statistical Measures for Numerical Columns:")
print(numerical_stats)
# Out:
# Basic Statistical Measures for Numerical Columns:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ...Explore the distribution of categorical
# variables like "Country Code,
#
# " "City,
#
# " and
#
# "Cuisines.
# "
#
# Identify the top cuisines and cities with the
# highest number of restaurants.

# %%
# Explore the distribution of categorical variables
country_distribution = df['Country Code'].value_counts()
city_distribution = df['City'].value_counts()
cuisine_distribution = df['Cuisines'].value_counts()

# %%
# Display the results
print("\nDistribution of Country Code:")
print(country_distribution)

print("\nDistribution of City:")
print(city_distribution)

print("\nDistribution of Cuisines:")
print(cuisine_distribution)
# Out:
# Distribution of Country Code:
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
# Distribution of City:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64
#
# Distribution of Cuisines:
# North Indian                                             945
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
# ...

# %%
# Identify the top cuisines and cities with the highest number of restaurants
top_cuisines = df['Cuisines'].value_counts().head(10)
top_cities = df['City'].value_counts().head(10)

# %%
# Display the top cuisines and cities
print("\nTop Cuisines:")
print(top_cuisines)

print("\nTop Cities:")
print(top_cities)
# Out:
# Top Cuisines:
# North Indian                      945
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64
#
# Top Cities:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: City, dtype: int64

# %% [markdown]
# # Task 3

# %% [markdown]
# ...Visualize the locations of restaurants on a
# map using latitude and longitude
# information.

# %%
pip install plotly pandas

# %%
# Create an interactive map using Plotly Express
import plotly.express as px
fig = px.scatter_mapbox(
    df,
    lat='Latitude',
    lon='Longitude',
    hover_name='Restaurant Name',
    zoom=10,
)

# %%
# Customize the map layout
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ...Analyze the distribution of restaurants
# across different cities or countries.
# Determine if there is any correlation
# between the restaurant's location and its
# rating.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Distribution of restaurants across different cities
city_distribution = df['City'].value_counts()
print("\nDistribution of Restaurants Across Different Cities:")
print(city_distribution)
# Out:
# Distribution of Restaurants Across Different Cities:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
# Distribution of restaurants across different countries
country_distribution = df['Country Code'].value_counts()
print("\nDistribution of Restaurants Across Different Countries:")
print(country_distribution)
# Out:
# Distribution of Restaurants Across Different Countries:
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
# Correlation between restaurant's location and its rating
correlation_matrix = df[['Latitude', 'Longitude', 'Aggregate rating']].corr()

# %%
# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix: Location vs. Rating')
plt.show()

# %% [markdown]
# # LEVEL 3

# %% [markdown]
# #Task 1

# %% [markdown]
# ...Build a regression model to predict the
# aggregate rating of a restaurant based on
# available features.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# Choose relevant features for prediction
features = df[['Average Cost for two', 'Votes', 'Price range']]

# %%
# Target variable
target = df['Aggregate rating']

# %% [markdown]
# ...Split the dataset into training and testing sets
# and evaluate the model's performance using
# appropriate metrics.

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create a decision tree regressor model
model = DecisionTreeRegressor(random_state=42)

# %%
# Train the model
model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Make predictions on the test set
predictions = model.predict(X_test_scaled)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print("\nModel Evaluation:")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Model Evaluation:
# Mean Squared Error: 0.20881358680676537
# R-squared: 0.9082585290529638

# %% [markdown]
# ...Experiment with different algorithms (e.g.,
# linear regression, decision trees, random
# forest) and compare their performance.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# Choose relevant features for prediction
features = df[['Average Cost for two', 'Votes', 'Price range']]

# Target variable
target = df['Aggregate rating']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize models
linear_model = LinearRegression()
decision_tree_model = DecisionTreeRegressor(random_state=42)
random_forest_model = RandomForestRegressor(random_state=42)

# Train models
linear_model.fit(X_train_scaled, y_train)
decision_tree_model.fit(X_train_scaled, y_train)
random_forest_model.fit(X_train_scaled, y_train)

# Make predictions
linear_predictions = linear_model.predict(X_test_scaled)
decision_tree_predictions = decision_tree_model.predict(X_test_scaled)
random_forest_predictions = random_forest_model.predict(X_test_scaled)

# Evaluate the models
linear_mse = mean_squared_error(y_test, linear_predictions)
linear_r2 = r2_score(y_test, linear_predictions)

decision_tree_mse = mean_squared_error(y_test, decision_tree_predictions)
decision_tree_r2 = r2_score(y_test, decision_tree_predictions)

random_forest_mse = mean_squared_error(y_test, random_forest_predictions)
random_forest_r2 = r2_score(y_test, random_forest_predictions)

# Display the results
print("\nModel Evaluation:")
print(f"Linear Regression - Mean Squared Error: {linear_mse}, R-squared: {linear_r2}")
print(f"Decision Tree - Mean Squared Error: {decision_tree_mse}, R-squared: {decision_tree_r2}")
print(f"Random Forest - Mean Squared Error: {random_forest_mse}, R-squared: {random_forest_r2}")
# Out:
# Model Evaluation:
# Linear Regression - Mean Squared Error: 1.7599302405948416, R-squared: 0.226781209472951
# Decision Tree - Mean Squared Error: 0.20881358680676537, R-squared: 0.9082585290529638
# Random Forest - Mean Squared Error: 0.14484626277579454, R-squared: 0.9363623344082044

# %% [markdown]
# In this comparison, the decision tree and random forest models outperform linear regression. The random forest model, in particular, demonstrates the best performance based on the provided metrics

# %% [markdown]
# # Task 2

# %% [markdown]
# ...Analyze the relationship between the type of
# cuisine and the restaurant's rating.

# %%
# Unique Visualization: Violin Plot for Cuisine Types and Ratings
plt.figure(figsize=(16, 8))
sns.violinplot(x='Cuisines', y='Aggregate rating', data=df, palette='Set1', inner='quartile', split=True)
plt.xticks(rotation=90)
plt.title('Distribution of Ratings for Different Cuisine Types (Violin Plot)')
plt.xlabel('Cuisine Type')
plt.ylabel('Aggregate Rating')
plt.show()

# %% [markdown]
# ...To identify the most popular cuisines among customers based on the number of votes, you can use the following code:

# %%
# Identify the most popular cuisines based on the number of votes
most_popular_cuisines = df.groupby('Cuisines')['Votes'].sum().sort_values(ascending=False).head(10)

print("\nTop 10 Most Popular Cuisines Based on Votes:")
print(most_popular_cuisines)
# Out:
# Top 10 Most Popular Cuisines Based on Votes:
# Cuisines
# North Indian, Mughlai             53747
# North Indian                      48967
# North Indian, Chinese             42012
# Cafe                              30657
# Chinese                           21925
# North Indian, Mughlai, Chinese    20115
# Fast Food                         17852
# South Indian                      16433
# Mughlai, North Indian             15275
# Italian                           14799
# Name: Votes, dtype: int64

# %% [markdown]
# ...Determine if there are any specific cuisines
# that tend to receive higher ratings.

# %%
# Calculate the average rating for each cuisine type
average_rating_by_cuisine = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

# Display the cuisines with the highest average ratings
print("\nTop Cuisines with the Highest Average Ratings:")
print(average_rating_by_cuisine.head(10))
# Out:
# Top Cuisines with the Highest Average Ratings:
# Cuisines
# Italian, Deli               4.9
# Hawaiian, Seafood           4.9
# American, Sandwich, Tea     4.9
# Continental, Indian         4.9
# European, Asian, Indian     4.9
# European, Contemporary      4.9
# European, German            4.9
# BBQ, Breakfast, Southern    4.9
# American, Coffee and Tea    4.9
# Sunda, Indonesian           4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# # Task 3

# %% [markdown]
# ...Create visualizations to represent the distribution
# of ratings using different charts (histogram, bar
# plot, etc.).

# %%
# Visualization 1: Histogram of Ratings
plt.figure(figsize=(10, 6))
sns.histplot(df['Aggregate rating'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Ratings (Histogram)')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# Visualization 2: Bar Plot of Rating Frequencies
plt.figure(figsize=(10, 6))
sns.countplot(x='Aggregate rating', data=df, palette='viridis')
plt.title('Rating Frequencies (Bar Plot)')
plt.xlabel('Aggregate Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ...Compare the average ratings of different cuisines
# or cities using appropriate visualizations.

# %%
# Visualization 1: Bar Plot of Average Ratings by Cuisine
plt.figure(figsize=(14, 8))
sns.barplot(x='Aggregate rating', y='Cuisines', data=df, ci=None, palette='viridis', orient='h')
plt.title('Average Ratings by Cuisine')
plt.xlabel('Average Rating')
plt.ylabel('Cuisine')
plt.show()

# Visualization 2: Bar Plot of Average Ratings by City
plt.figure(figsize=(14, 8))
sns.barplot(x='Aggregate rating', y='City', data=df, ci=None, palette='muted', orient='h')
plt.title('Average Ratings by City')
plt.xlabel('Average Rating')
plt.ylabel('City')
plt.show()
# Out:
# <ipython-input-50-9086a5888e70>:3: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
# <ipython-input-50-9086a5888e70>:11: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %% [markdown]
# ...Visualize the relationship between various
# features and the target variable to gain insights.

# %%
# Select relevant numerical features for visualization
numerical_features = df[['Average Cost for two', 'Votes', 'Price range', 'Aggregate rating']]

# Pair plot for visualizing relationships
sns.pairplot(numerical_features, height=2, aspect=2, kind='scatter', palette='viridis')
plt.suptitle('Pair Plot of Numerical Features and Aggregate Rating', y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning:
#
# ...
